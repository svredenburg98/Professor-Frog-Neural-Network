# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)

# %%
image_size = (224, 224)
image_path = os.path.join("frog_pics", "frog_12.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
x = image.img_to_array(img)
#x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
x
# Out:
# array([[[ -60.939003 ,   24.221    ,   95.32     ],
#         [ -45.939003 ,   44.221    ,  100.32     ],
#         [ -60.939003 ,   29.221    ,   84.32     ],
#         ...,
#         [  19.060997 ,  -19.779    ,  -92.68     ],
#         [ 105.061    ,   67.221    ,  -31.68     ],
#         [  79.061    ,   47.221    ,  -86.68     ]],
#
#        [[ -62.939003 ,   22.221    ,   93.32     ],
#         [ -48.939003 ,   41.221    ,   97.32     ],
#         [ -60.939003 ,   29.221    ,   84.32     ],
#         ...,
#         [  21.060997 ,  -19.779    ,  -91.68     ],
#         [ 109.061    ,   71.221    ,  -27.68     ],
#         [  82.061    ,   48.221    ,  -80.68     ]],
#
#        [[ -61.939003 ,   23.221    ,   94.32     ],
#         [ -48.939003 ,   41.221    ,   97.32     ],
#         [ -60.939003 ,   29.221    ,   84.32     ],
#         ...,
#         [  23.060997 ,  -16.779    ,  -90.68     ],
#         [ 102.061    ,   62.221    ,  -35.68     ],
#         [ 112.061    ,   75.221    ,  -51.68     ]],
#
#        ...,
#
#        [[-101.939    ,  -81.779    ,  -25.68     ],
#         [ -95.939    ,  -83.779    ,  -34.68     ],
#         [ -95.939    ,  -86.779    ,  -35.68     ],
#         ...,
#         [-101.939    ,  -41.779    ,   72.32     ],
#         [ -81.939    ,  -29.779    ,   72.32     ],
#         [ -82.939    ,  -44.779    ,   44.32     ]],
#
#        [[ -88.939    ,  -74.779    ,    4.3199997],
#         [ -93.939    ,  -75.779    ,    2.3199997],
#         [-102.939    ,  -76.779    ,    1.3199997],
#         ...,
#         [ -78.939    ,  -26.779    ,   71.32     ],
#         [ -72.939    ,  -29.779    ,   58.32     ],
#         [-103.939    ,  -77.779    ,    0.3199997]],
#
#        [[ -99.939    ,  -75.779    ,   -8.68     ],
#         [ -94.939    ,  -59.779    ,   21.32     ],
#         [ -73.939    ,  -35.779    ,   49.32     ],
#         ...,
#         [ -94.939    ,  -53.779    ,   24.32     ],
#         [-103.939    ,  -78.779    ,   -8.68     ],
#         [ -90.939    ,  -72.779    ,  -10.68     ]]], dtype=float32)

# %%
image.array_to_img(
    x, data_format=None, scale=True, dtype=None
)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2E6EB4AED48>
